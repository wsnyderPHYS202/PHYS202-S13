# %% [markdown]
# ###Ex. 1

# %% [markdown]
# ####(a)

# %%
data = loadtxt('radioactivedecay.dat')
print data
# Out:
# [[  0.    10.48]
#  [  1.     7.54]
#  [  2.     5.49]
#  [  3.     4.02]
#  [  4.     2.74]
#  [  5.     2.02]
#  [  6.     1.5 ]
#  [  7.     1.09]
#  [  8.     0.68]
#  [  9.     0.57]
#  [ 10.     0.37]
#  [ 11.     0.31]
#  [ 12.     0.19]
#  [ 13.     0.15]
#  [ 14.     0.13]
#  [ 15.     0.11]]

# %%
figure(figsize = (8,6))

plot(data[0:,0],data[0:,1],'b*', label = 'Radioactive Decay')
legend(loc = 'best')
show()

# %%
lnt = log(data[1:,0])
lnN = log(data[1:,1])
print lnt
print lnN
plot(lnt, lnN)
show()
# Out:
# [ 0.          0.69314718  1.09861229  1.38629436  1.60943791  1.79175947
#   1.94591015  2.07944154  2.19722458  2.30258509  2.39789527  2.48490665
#   2.56494936  2.63905733  2.7080502 ]
# [ 2.02022218  1.70292826  1.3912819   1.00795792  0.70309751  0.40546511
#   0.0861777  -0.38566248 -0.56211892 -0.99425227 -1.17118298 -1.66073121
#  -1.89711998 -2.04022083 -2.20727491]
