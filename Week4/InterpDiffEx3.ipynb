# %% [markdown]
# ## Interpolation and Numerical Dierentiation, Exercises 3

# %% [markdown]
# ###Problem 1

# %%
from Electrostatics import *
x,y = meshgrid(arange(-5,5,0.5),arange(-5,5,0.5))
Vdipole = dipolePotential(x,y,1e-9,2.);
contour(x,y,Vdipole,cmap=cm.gist_earth_r)
show()

# %% [markdown]
# ####(a)
