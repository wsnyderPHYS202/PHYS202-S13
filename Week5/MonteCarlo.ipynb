# %% [markdown]
# ## Monte Carlo Integration

# %% [markdown]
# ### Ex.1

# %%
f = lambda x: x**.5 + sin(x)

# %%
x = arange(0.,15.,0.001)

# %%
myplot = plot(x,f(x),lw=3)
ylabel(r'$x^{1/2} + \sin(x)$', fontsize=20)
xlabel(r'$x$', fontsize = 20)
xlim(0.,15.)

show()

# %%
xmin = 1.7
xmax = 12.4

subx = x[logical_and((x>xmin),(x<xmax))]
ymax = max(f(subx))*1.05
ymin = 0.

myplot = plot(x,f(x),lw = 3)
xlim = (0.,15.)

plot([xmin,xmin],[ymin,ymax], color = 'k', linestyle = '--')
plot([xmax,xmax],[ymin,ymax], color = 'k', linestyle = '--')
plot([xmin,xmax],[ymax,ymax], color = 'k', linestyle = '--')

show()

# %%
N = 10000000
samples_x = xmin + (xmax - xmin)*random_sample(N);
samples_y = ymin + (ymax - ymin)*random_sample(N);

myplot = plot(x,f(x),lw = 3)
xlim = (0.,15.)

plot(samples_x[1:200], samples_y[1:200], '.')

plot([xmin,xmin],[ymin,ymax], color = 'k', linestyle = '--')
plot([xmax,xmax],[ymin,ymax], color = 'k', linestyle = '--')
plot([xmin,xmax],[ymax,ymax], color = 'k', linestyle = '--')

show()

# %%
newmask = (samples_y < f(samples_x))

# %%
sum(newmask)
# Out:
# 6181578

# %%
myplot = plot(x,f(x),lw = 3)
xlim = (0.,15.)

plot(samples_x[1:200], samples_y[1:200], '.')

plot(samples_x[newmask[:200]], samples_y[newmask[:200]], 'r.')

plot([xmin,xmin],[ymin,ymax], color = 'k', linestyle = '--')
plot([xmax,xmax],[ymin,ymax], color = 'k', linestyle = '--')
plot([xmin,xmax],[ymax,ymax], color = 'k', linestyle = '--')

show()

# %%
I = (xmax - xmin)*(ymax-ymin)* sum(newmask)/newmask.size
print I
# Out:
# 26.5179310438

# %%
Iana = lambda x: (2./3.)*x**(3./2.) - cos(x)
Iexact = Iana(xmax) - Iana(xmin)
Ierr = 100*abs((Iexact - I))/Iexact

print "I_exact =",Iexact
print "I_hitormiss =",I
print "Error on I =",Ierr, "%"
# Out:
# I_exact = 26.5172145362
# I_hitormiss = 26.5179310438
# Error on I = 0.00270204703507 %

# %% [markdown]
# ### Ex.2

# %% [markdown]
# #### (a)

# %%
f = lambda x: x**.5 + sin(x)

N = 10000
xi = linspace(xmin,xmax,N)
xmin = 1.7
xmax = 12.4

b_a = xmax - xmin
A = 1./N
C = b_a * A
print C
# Out:
# 0.00107

# %%
tot = 0.
for q in xi:
    tot += f(q)
sumMean = C*tot
print sumMean
# Out:
# 26.5175863246

# %% [markdown]
# #### (b)

# %%
subx = x[logical_and((x>xmin),(x<xmax))]
ymax = max(f(subx))*1.05
ymin = 0.

avg = tot*A
yavg = np.ones(x.size) * avg

# %%
myplot = plot(x,f(x),lw = 3)
xlim = (0.,15.)

plot([xmin,xmin],[ymin,ymax], color = 'k', linestyle = '--')
plot([xmax,xmax],[ymin,ymax], color = 'k', linestyle = '--')
plot([xmin,xmax],[ymax,ymax], color = 'k', linestyle = '--')

plot([xmin,xmax],[yavg,yavg], color = 'r', linewidth = 3)

show()

# %% [markdown]
# #### (c)

# %%
Iana = lambda x: (2./3.)*x**(3./2.) - cos(x)
Iexact = Iana(xmax) - Iana(xmin)
Ierr = 100*abs((Iexact - sumMean))/sumMean

print "I_exact =",Iexact
print "I_sumMean =",sumMean
print "Error on I =",Ierr, "%"
print
print 'Difference between Hit-or-Miss and Sum Mean:', abs(sumMean-I), '%'
# Out:
# I_exact = 26.5172145362
# I_sumMean = 26.5175863246
# Error on I = 0.00140204464654 %
#
# Difference between Hit-or-Miss and Sum Mean: 0.000344719209703 %

# %% [markdown]
# ### Ex.3

# %%
import sys
sys.path.insert(0, '../Week4')
from Electrostatics import *

# %%
N = 10000
    
phiMax = 2*pi; rMax = 0.012;
phi = phiMax*random_sample(N);
r = rMax*random_sample(N);

sigma = 2e-9
x0 = 2.
y0 = 3.
xi2 = r * cos(phi)
yi2 = r * sin(phi)

Vi2 = pointPotential(x0,y0,sigma, xi2, yi2)

totalVoltage = (phiMax*rMax/N)*sum(Vi2)
print totalVoltage,'Volts'
# Out:
# 0.37599159968 Volts
